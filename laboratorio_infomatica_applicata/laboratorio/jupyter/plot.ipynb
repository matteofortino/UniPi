# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Davide gay?")
plt.plot([1,2,3,4], [5,6,7,8])
plt.show()
# Out:
# yes

# %%
x = np.linspace(0, 1, 200)
y = np.sin((2 * np.pi * x) ** 2)
plt.plot(x,y, "red")
plt.show()

# %%
x = 10 * np.random.rand(200, 1)
y = (0.2 + 0.8 * x) * np.sin(2 * np.pi * x) + np.random.rand(200, 1)
plt.hist(y, bins=20)
# Out:
# (array([ 6.,  5.,  6.,  5.,  5., 11.,  9.,  6., 16., 23., 24., 12., 13.,
#         12.,  8., 14.,  7.,  7.,  9.,  2.]),
#  array([-7.2070357 , -6.4496336 , -5.6922315 , -4.9348294 , -4.17742731,
#         -3.42002521, -2.66262311, -1.90522101, -1.14781891, -0.39041682,
#          0.36698528,  1.12438738,  1.88178948,  2.63919158,  3.39659367,
#          4.15399577,  4.91139787,  5.66879997,  6.42620207,  7.18360416,
#          7.94100626]),
#  <BarContainer object of 20 artists>)

# %%
import numpy as np 
import matplotlib.pyplot as plt

data = np.random.rand(32, 32)

plt.style.use("seaborn-v0_8-whitegrid")

plt.imshow(data, cmap="viridis")
plt.colorbar()

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(10*x)
plt.plot(x,y)

# %%
import pandas as pd 

s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series(np.arange(5), dtype=np.uint8)
print(type(s1))
print(s2)
# Out:
# <class 'pandas.Series'>
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: uint8

# %%
import pandas as pd 
file = pd.read_csv("leads-10000.csv")
file.describe()
file.head()
# Out:
#    Index       Account Id     Lead Owner First Name Last Name  \
# 0      1  2FCBFE58CC70308   Selena Doyle      Jaime     Hayes
# 1      2  f16E4f6a6c741db  Kelsey Mosley       Cody   Salinas
# 2      3  B7FfE9C1dc2E360  Anne Franklin    Leonard    Rogers
# 3      4  cafEef0A3D728a7  Darlene Hurst     Manuel    Lowery
# 4      5  917224BC3bdcA89    Nina Chavez       Dawn  Anderson
#
#                          Company                 Phone 1            Phone 2  \
# 0                       Mays Inc              9802005297  917-584-0243x4606
# 1                Blankenship Inc            369.329.6963  834.998.8869x2671
# 2                    Wells-Burch      409.411.1126x05090  548.320.4326x6724
# 3        Mooney, Salinas and Ali  001-307-937-7505x54026   754.386.8611x687
# 4  Compton, Mcmillan and Aguirre           (704)585-7792  479.490.9915x8579
#
#                          Email 1                             Email 2  \
# 0        fstephens@shepherd.info               rusheddie@massey.info
# 1               ariel63@hunt.com  rittergilbert@stokes-mccormick.com
# 2  marciaburns@miles-brennan.com      acrawford@bradford-norris.info
# 3   norman05@cummings-forbes.com             vwolf@foster-zuniga.org
# 4    mezasheryl@santana-york.com           craigdominique@steele.org
#
#                       Website             Source     Deal Stage  \
# 0          https://black.com/  LinkedIn Outreach        On Hold
# 1         https://austin.org/          Cold Call        On Hold
# 2      http://www.sutton.net/           Referral  Re-engagement
# 3  http://www.washington.com/   Networking Event  Re-engagement
# 4        http://www.yang.net/       Website Form     Closed Won
#
#                                                Notes
# 0                        Heart represent while into.
# 1   Partner school law vote responsibility team air.
# 2      Never structure myself art middle carry hope.
# 3  Institution example consider itself scene mode...
# 4  Miss government analysis use total west serve ...

# %%
import pandas as pd 

iris = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")
iris.head()
print(iris.groupby("species"))
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50
